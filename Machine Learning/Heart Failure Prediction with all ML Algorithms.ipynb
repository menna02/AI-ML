# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.linear_model import LogisticRegression, RidgeClassifier, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, ExtraTreesClassifier, AdaBoostClassifier, VotingClassifier, StackingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, log_loss

# %% [markdown]
# ### Data Importing

# %%
df = pd.read_csv("/kaggle/input/heart-failure-prediction/heart.csv")
data = df.copy()

# %% [markdown]
# #### Exploratery Data Analysis (EDA)

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# #### Define features and Target

# %%
X = data.iloc[:, :-1]
y= data.iloc[:, -1]

# %%
X.sample(5)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 390   51   M           ASY        140            0          0     Normal
# 699   57   M           ASY        110          201          0     Normal
# 698   41   M           NAP        130          214          0        LVH
# 387   53   M           ASY        130            0          0        LVH
# 806   70   M           ASY        145          174          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 390     60              N      0.0     Flat
# 699    126              Y      1.5     Flat
# 698    168              N      2.0     Flat
# 387    135              Y      1.0     Flat
# 806    125              Y      2.6     Down

# %% [markdown]
# #### Encode Object Data

# %%
encoder = LabelEncoder()
object_cols = X.select_dtypes(include=['object'])
object_cols
# Out:
#     Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# 0     M           ATA     Normal              N       Up
# 1     F           NAP     Normal              N     Flat
# 2     M           ATA         ST              N       Up
# 3     F           ASY     Normal              Y     Flat
# 4     M           NAP     Normal              N       Up
# ..   ..           ...        ...            ...      ...
# 913   M            TA     Normal              N     Flat
# 914   M           ASY     Normal              N     Flat
# 915   M           ASY     Normal              Y     Flat
# 916   F           ATA        LVH              N     Flat
# 917   M           NAP     Normal              N       Up
#
# [918 rows x 5 columns]

# %%
for col in object_cols.columns:
    X[col]=encoder.fit_transform(object_cols[col])

# %%
X.sample(5)
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 333   40    1              0         95            0          1           2
# 818   51    1              0        140          299          0           1
# 341   64    1              0        110            0          1           1
# 601   61    1              2        140          284          0           1
# 279   54    0              1        130          253          0           2
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# 333    144               0      0.0         2
# 818    173               1      1.6         2
# 341    114               1      1.3         0
# 601    123               1      1.3         1
# 279    155               0      0.0         2

# %% [markdown]
# #### Data splitting for train and test

# %%
X_train, X_test,y_train , y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_test
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 668   63    0              1        140          195          0           1
# 30    53    1              2        145          518          0           1
# 377   65    1              0        160            0          1           2
# 535   56    1              0        130            0          0           0
# 807   54    1              1        108          309          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 468   62    1              0        152          153          0           2
# 66    45    0              0        132          297          0           1
# 332   38    1              2        100            0          0           1
# 375   73    0              2        160            0          0           2
# 381   50    1              0        115            0          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# 668    179               0      0.0         2
# 30     130               0      0.0         1
# 377    122               0      1.2         1
# 535    122               1      1.0         1
# 807    156               0      0.0         2
# ..     ...             ...      ...       ...
# 468     97               1      1.6         2
# 66     144               0      0.0         2
# 332    179               0     -1.1         2
# 375    121               0      0.0         2
# 381    120               1      0.5         1
#
# [92 rows x 11 columns]

# %% [markdown]
# #### Data Scaling

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)
X_train
# Out:
# array([[ 0.26942112,  0.52786151,  1.30345598, ...,  1.20157687,
#          0.85419999, -0.61468478],
#        [-0.79895068,  0.52786151,  0.24687635, ...,  1.20157687,
#         -0.8288434 ,  1.05547847],
#        [-1.54681094,  0.52786151,  0.24687635, ...,  1.20157687,
#          0.1061807 , -0.61468478],
#        ...,
#        [ 0.69676984,  0.52786151, -0.80970327, ...,  1.20157687,
#          0.48019035,  1.05547847],
#        [ 0.69676984,  0.52786151, -0.80970327, ...,  1.20157687,
#         -0.8288434 ,  1.05547847],
#        [-1.43997376, -1.8944363 , -0.80970327, ..., -0.83223972,
#          1.04120481, -0.61468478]])

# %%
X_test
# Out:
# array([[ 1.01728138, -1.8944363 ,  0.24687635, ..., -0.83223972,
#         -0.8288434 ,  1.05547847],
#        [-0.05109042,  0.52786151,  1.30345598, ..., -0.83223972,
#         -0.8288434 , -0.61468478],
#        [ 1.23095574,  0.52786151, -0.80970327, ..., -0.83223972,
#          0.29318553, -0.61468478],
#        ...,
#        [-1.65364812,  0.52786151,  1.30345598, ..., -0.83223972,
#         -1.85736992,  1.05547847],
#        [ 2.08565318, -1.8944363 ,  1.30345598, ..., -0.83223972,
#         -0.8288434 ,  1.05547847],
#        [-0.37160196,  0.52786151, -0.80970327, ...,  1.20157687,
#         -0.36133135, -0.61468478]])

# %% [markdown]
# ### Machine Learning Algorithms

# %% [markdown]
# #### Logistic Regression

# %%
lr = LogisticRegression(penalty='l2', C=1, max_iter=100)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1)

# %%
print("Train Accuracy:",lr.score(X_train, y_train))
# Out:
# Train Accuracy: 0.860774818401937

# %%
y_pred = lr.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
# Out:
# Test Accuracy: 0.8586956521739131

# %%
print("Precision Score", precision_score(y_test, y_pred))
print("Recall Score", recall_score(y_test, y_pred))
print("F1 Score", f1_score(y_test, y_pred))
# Out:
# Precision Score 0.8867924528301887
# Recall Score 0.8703703703703703
# F1 Score 0.8785046728971964

# %% [markdown]
# #### SGD Classifier

# %%
sgd = SGDClassifier(penalty='l1',learning_rate='adaptive', eta0=0.0001)
sgd.fit(X_train, y_train)
# Out:
# SGDClassifier(eta0=0.0001, learning_rate='adaptive', penalty='l1')

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",sgd.score(X_train, y_train))
y_pred = sgd.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.8535108958837773
# Test Accuracy: 0.8369565217391305
# Classification Report               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        38
#            1       0.88      0.83      0.86        54
#
#     accuracy                           0.84        92
#    macro avg       0.83      0.84      0.83        92
# weighted avg       0.84      0.84      0.84        92

# %% [markdown]
# #### SVM Classifier
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC)

# %%
svc = SVC(C=3)
svc.fit(X_train, y_train)
# Out:
# SVC(C=3)

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",svc.score(X_train, y_train))
y_pred = svc.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.9249394673123487
# Test Accuracy: 0.8913043478260869
# Classification Report               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.88        38
#            1       0.94      0.87      0.90        54
#
#     accuracy                           0.89        92
#    macro avg       0.89      0.90      0.89        92
# weighted avg       0.90      0.89      0.89        92

# %% [markdown]
# #### Decision Tree Classifier
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",dtree.score(X_train, y_train))
y_pred = dtree.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.8369565217391305
# Classification Report               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.81        38
#            1       0.90      0.81      0.85        54
#
#     accuracy                           0.84        92
#    macro avg       0.83      0.84      0.83        92
# weighted avg       0.84      0.84      0.84        92

# %% [markdown]
# The decision tree model has been overfitted

# %% [markdown]
# #### K-Neighbors Classifier
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier)

# %%
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",knn.score(X_train, y_train))
y_pred = knn.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.8753026634382567
# Test Accuracy: 0.8695652173913043
# Classification Report               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        38
#            1       0.89      0.89      0.89        54
#
#     accuracy                           0.87        92
#    macro avg       0.87      0.87      0.87        92
# weighted avg       0.87      0.87      0.87        92

# %% [markdown]
# ### Ensemble Models

# %% [markdown]
# #### Random Forest Classifier
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier)

# %%
rfc = RandomForestClassifier(n_estimators=70, random_state=42)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=70, random_state=42)

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",rfc.score(X_train, y_train))
y_pred = rfc.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.8804347826086957
# Classification Report               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86        38
#            1       0.91      0.89      0.90        54
#
#     accuracy                           0.88        92
#    macro avg       0.88      0.88      0.88        92
# weighted avg       0.88      0.88      0.88        92

# %% [markdown]
# #### Bagging Classifier
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingClassifier.html#sklearn.ensemble.BaggingClassifier)

# %%
bclf_rfc = BaggingClassifier(estimator=rfc,n_estimators=120, random_state=5 )
bclf_rfc.fit(X_train, y_train)
# Out:
# BaggingClassifier(estimator=RandomForestClassifier(n_estimators=70,
#                                                    random_state=42),
#                   n_estimators=120, random_state=5)

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",bclf_rfc.score(X_train, y_train))
y_pred = bclf_rfc.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.9757869249394673
# Test Accuracy: 0.8804347826086957
# Classification Report               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85        38
#            1       0.88      0.93      0.90        54
#
#     accuracy                           0.88        92
#    macro avg       0.88      0.87      0.88        92
# weighted avg       0.88      0.88      0.88        92

# %% [markdown]
# #### Extra Trees Classifier
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html#sklearn.ensemble.ExtraTreesClassifier)

# %%
etclf = ExtraTreesClassifier(n_estimators=350, random_state=5 )
etclf.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(n_estimators=350, random_state=5)

# %%
print("Train Accuracy:",etclf.score(X_train, y_train))
y_pred = etclf.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.8913043478260869
# Classification Report               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        38
#            1       0.91      0.91      0.91        54
#
#     accuracy                           0.89        92
#    macro avg       0.89      0.89      0.89        92
# weighted avg       0.89      0.89      0.89        92

# %% [markdown]
# #### Adaptive Boost Classifier
# using Bagging Classifier as an estimator
#
#
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html#sklearn.ensemble.AdaBoostClassifier)

# %%
adb_clf = AdaBoostClassifier(estimator= bclf_rfc, n_estimators=100)
adb_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=BaggingClassifier(estimator=RandomForestClassifier(n_estimators=70,
#                                                                                 random_state=42),
#                                                n_estimators=120,
#                                                random_state=5),
#                    n_estimators=100)

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",adb_clf.score(X_train, y_train))
y_pred = adb_clf.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.9830508474576272
# Test Accuracy: 0.8913043478260869
# Classification Report               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        38
#            1       0.91      0.91      0.91        54
#
#     accuracy                           0.89        92
#    macro avg       0.89      0.89      0.89        92
# weighted avg       0.89      0.89      0.89        92

# %% [markdown]
# #### Voting Classifier
# using SVC and Random Forest as estimators
#
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html#sklearn.ensemble.VotingClassifier)

# %%
voting_clf = VotingClassifier(estimators=[('SVC',svc),('Random Forest',rfc), ('LR',lr), ('ExtraTreesClf',etclf)], weights=[2,1,1,1]  )
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('SVC', SVC(C=3)),
#                              ('Random Forest',
#                               RandomForestClassifier(n_estimators=70,
#                                                      random_state=42)),
#                              ('LR', LogisticRegression(C=1)),
#                              ('ExtraTreesClf',
#                               ExtraTreesClassifier(n_estimators=350,
#                                                    random_state=5))],
#                  weights=[2, 1, 1, 1])

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",voting_clf.score(X_train, y_train))
y_pred = voting_clf.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.9297820823244553
# Test Accuracy: 0.9021739130434783
# Classification Report               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88        38
#            1       0.92      0.91      0.92        54
#
#     accuracy                           0.90        92
#    macro avg       0.90      0.90      0.90        92
# weighted avg       0.90      0.90      0.90        92

# %% [markdown]
# #### Stacking Classifier
# [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingClassifier.html#sklearn.ensemble.StackingClassifier)

# %%
st_clf = StackingClassifier(estimators=[('SVC',svc),("LogisticRegression",lr),('Random Forest',rfc)])
st_clf.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('SVC', SVC(C=3)),
#                                ('LogisticRegression', LogisticRegression(C=1)),
#                                ('Random Forest',
#                                 RandomForestClassifier(n_estimators=70,
#                                                        random_state=42))])

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",st_clf.score(X_train, y_train))
y_pred = st_clf.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.9539951573849879
# Test Accuracy: 0.8913043478260869
# Classification Report               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        38
#            1       0.91      0.91      0.91        54
#
#     accuracy                           0.89        92
#    macro avg       0.89      0.89      0.89        92
# weighted avg       0.89      0.89      0.89        92

# %% [markdown]
# #### Extra Gradiant Boost Classifier
# [Link](https://xgboost.readthedocs.io/en/stable/parameter.html)

# %%
xgbc = XGBClassifier(n_estimators=130, random_state=42, learning_rate=0.01)
xgbc.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=130, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
print("Train Accuracy:",xgbc.score(X_train, y_train))
y_pred = xgbc.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.937046004842615
# Test Accuracy: 0.8913043478260869
# Classification Report               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86        38
#            1       0.89      0.93      0.91        54
#
#     accuracy                           0.89        92
#    macro avg       0.89      0.88      0.89        92
# weighted avg       0.89      0.89      0.89        92

# %% [markdown]
# #### Cat Boost Classifier
# [Link](https://catboost.ai/en/docs/concepts/python-reference_catboostclassifier)

# %%
catboost = CatBoostClassifier(learning_rate=0.01,random_seed=42, n_estimators=500)
catboost.fit(X_train, y_train)
# Out:
# 0:	learn: 0.6839641	total: 1.5ms	remaining: 749ms
# 1:	learn: 0.6748070	total: 2.93ms	remaining: 730ms
# 2:	learn: 0.6669105	total: 4.28ms	remaining: 710ms
# 3:	learn: 0.6593535	total: 5.65ms	remaining: 701ms
# 4:	learn: 0.6517178	total: 6.95ms	remaining: 688ms
# 5:	learn: 0.6438603	total: 8.17ms	remaining: 673ms
# 6:	learn: 0.6371084	total: 9.42ms	remaining: 664ms
# 7:	learn: 0.6304239	total: 10.4ms	remaining: 637ms
# 8:	learn: 0.6230278	total: 11.5ms	remaining: 629ms
# 9:	learn: 0.6158020	total: 12.7ms	remaining: 622ms
# 10:	learn: 0.6091513	total: 14ms	remaining: 622ms
# 11:	learn: 0.6019573	total: 15.2ms	remaining: 619ms
# 12:	learn: 0.5957118	total: 16.5ms	remaining: 620ms
# 13:	learn: 0.5902175	total: 17.8ms	remaining: 619ms
# 14:	learn: 0.5838495	total: 19.1ms	remaining: 618ms
# 15:	learn: 0.5768315	total: 20.4ms	remaining: 616ms
# 16:	learn: 0.5709332	total: 21.6ms	remaining: 615ms
# 17:	learn: 0.5654075	total: 22.8ms	remaining: 611ms
# 18:	learn: 0.5590252	total: 24ms	remaining: 609ms
# 19:	learn: 0.5523922	total: 25.3ms	remaining: 608ms
# 20:	learn: 0.5464882	total: 26.7ms	remaining: 608ms
# 21:	learn: 0.5433728	total: 27.5ms	remaining: 599ms
# 22:	learn: 0.5382210	total: 28.6ms	remaining: 593ms
# 23:	learn: 0.5326144	total: 29.8ms	remaining: 592ms
# 24:	learn: 0.5272020	total: 31.1ms	remaining: 592ms
# 25:	learn: 0.5221370	total: 32.4ms	remaining: 590ms
# 26:	learn: 0.5172740	total: 33.5ms	remaining: 588ms
# 27:	learn: 0.5129703	total: 34.8ms	remaining: 587ms
# 28:	learn: 0.5087731	total: 36.2ms	remaining: 588ms
# 29:	learn: 0.5040630	total: 37.4ms	remaining: 586ms
# 30:	learn: 0.4994473	total: 38.7ms	remaining: 586ms
# 31:	learn: 0.4942911	total: 40.1ms	remaining: 586ms
# 32:	learn: 0.4923094	total: 40.8ms	remaining: 578ms
# 33:	learn: 0.4886354	total: 42.1ms	remaining: 576ms
# 34:	learn: 0.4838404	total: 43.4ms	remaining: 576ms
# 35:	learn: 0.4796805	total: 44.7ms	remaining: 576ms
# 36:	learn: 0.4760883	total: 45.9ms	remaining: 574ms
# 37:	learn: 0.4722049	total: 47.1ms	remaining: 573ms
# 38:	learn: 0.4676441	total: 48.4ms	remaining: 572ms
# 39:	learn: 0.4639216	total: 49.6ms	remaining: 571ms
# 40:	learn: 0.4603888	total: 50.8ms	remaining: 569ms
# 41:	learn: 0.4565749	total: 52.1ms	remaining: 568ms
# 42:	learn: 0.4530051	total: 53.3ms	remaining: 566ms
# 43:	learn: 0.4493624	total: 54.5ms	remaining: 565ms
# 44:	learn: 0.4463195	total: 55.8ms	remaining: 565ms
# 45:	learn: 0.4432541	total: 57ms	remaining: 563ms
# 46:	learn: 0.4416557	total: 57.7ms	remaining: 556ms
# 47:	learn: 0.4381911	total: 58.9ms	remaining: 555ms
# 48:	learn: 0.4349764	total: 60.1ms	remaining: 554ms
# 49:	learn: 0.4316927	total: 61.4ms	remaining: 553ms
# 50:	learn: 0.4288430	total: 62.7ms	remaining: 552ms
# 51:	learn: 0.4258232	total: 64ms	remaining: 552ms
# 52:	learn: 0.4231087	total: 65.3ms	remaining: 551ms
# 53:	learn: 0.4201528	total: 66.6ms	remaining: 550ms
# 54:	learn: 0.4181940	total: 67.9ms	remaining: 549ms
# 55:	learn: 0.4149302	total: 69.2ms	remaining: 549ms
# 56:	learn: 0.4124694	total: 70.4ms	remaining: 547ms
# 57:	learn: 0.4094034	total: 71.6ms	remaining: 546ms
# 58:	learn: 0.4067336	total: 73ms	remaining: 546ms
# 59:	learn: 0.4041480	total: 74.3ms	remaining: 545ms
# 60:	learn: 0.4017474	total: 75.5ms	remaining: 543ms
# 61:	learn: 0.3991135	total: 76.7ms	remaining: 542ms
# 62:	learn: 0.3976927	total: 77.5ms	remaining: 538ms
# 63:	learn: 0.3959522	total: 78.5ms	remaining: 535ms
# 64:	learn: 0.3936365	total: 79.7ms	remaining: 533ms
# 65:	learn: 0.3913826	total: 81ms	remaining: 533ms
# 66:	learn: 0.3891211	total: 82.3ms	remaining: 532ms
# 67:	learn: 0.3880757	total: 83.1ms	remaining: 528ms
# 68:	learn: 0.3861011	total: 84.4ms	remaining: 527ms
# 69:	learn: 0.3838954	total: 85.7ms	remaining: 526ms
# 70:	learn: 0.3827298	total: 86.5ms	remaining: 522ms
# 71:	learn: 0.3803715	total: 87.7ms	remaining: 522ms
# 72:	learn: 0.3780247	total: 89ms	remaining: 521ms
# 73:	learn: 0.3763299	total: 90.3ms	remaining: 520ms
# 74:	learn: 0.3748919	total: 91.7ms	remaining: 520ms
# 75:	learn: 0.3730752	total: 93ms	remaining: 519ms
# 76:	learn: 0.3711333	total: 94.3ms	remaining: 518ms
# 77:	learn: 0.3695059	total: 95.6ms	remaining: 517ms
# 78:	learn: 0.3672048	total: 96.8ms	remaining: 516ms
# 79:	learn: 0.3654441	total: 98ms	remaining: 515ms
# 80:	learn: 0.3639229	total: 99.2ms	remaining: 513ms
# 81:	learn: 0.3623501	total: 100ms	remaining: 512ms
# 82:	learn: 0.3603957	total: 102ms	remaining: 511ms
# 83:	learn: 0.3583835	total: 103ms	remaining: 510ms
# 84:	learn: 0.3563982	total: 104ms	remaining: 509ms
# 85:	learn: 0.3551358	total: 106ms	remaining: 508ms
# 86:	learn: 0.3535754	total: 107ms	remaining: 507ms
# 87:	learn: 0.3517748	total: 109ms	remaining: 508ms
# 88:	learn: 0.3505251	total: 110ms	remaining: 508ms
# 89:	learn: 0.3490869	total: 111ms	remaining: 507ms
# 90:	learn: 0.3476730	total: 113ms	remaining: 506ms
# 91:	learn: 0.3463788	total: 114ms	remaining: 505ms
# 92:	learn: 0.3447831	total: 115ms	remaining: 504ms
# 93:	learn: 0.3435391	total: 116ms	remaining: 503ms
# 94:	learn: 0.3428055	total: 117ms	remaining: 501ms
# 95:	learn: 0.3412012	total: 119ms	remaining: 500ms
# 96:	learn: 0.3405325	total: 120ms	remaining: 497ms
# 97:	learn: 0.3389520	total: 121ms	remaining: 495ms
# 98:	learn: 0.3373958	total: 122ms	remaining: 494ms
# 99:	learn: 0.3361173	total: 123ms	remaining: 493ms
# 100:	learn: 0.3351042	total: 125ms	remaining: 492ms
# 101:	learn: 0.3337579	total: 126ms	remaining: 491ms
# 102:	learn: 0.3327435	total: 127ms	remaining: 490ms
# 103:	learn: 0.3314808	total: 128ms	remaining: 489ms
# 104:	learn: 0.3305820	total: 130ms	remaining: 489ms
# 105:	learn: 0.3287987	total: 131ms	remaining: 487ms
# 106:	learn: 0.3279855	total: 132ms	remaining: 486ms
# 107:	learn: 0.3265915	total: 134ms	remaining: 485ms
# 108:	learn: 0.3256570	total: 135ms	remaining: 484ms
# 109:	learn: 0.3246059	total: 136ms	remaining: 483ms
# 110:	learn: 0.3230730	total: 137ms	remaining: 482ms
# 111:	learn: 0.3216557	total: 139ms	remaining: 481ms
# 112:	learn: 0.3207330	total: 140ms	remaining: 479ms
# 113:	learn: 0.3199480	total: 141ms	remaining: 478ms
# 114:	learn: 0.3189394	total: 142ms	remaining: 477ms
# 115:	learn: 0.3179049	total: 144ms	remaining: 476ms
# 116:	learn: 0.3167666	total: 145ms	remaining: 475ms
# 117:	learn: 0.3158236	total: 146ms	remaining: 474ms
# 118:	learn: 0.3148098	total: 148ms	remaining: 473ms
# 119:	learn: 0.3134398	total: 149ms	remaining: 472ms
# 120:	learn: 0.3126032	total: 150ms	remaining: 471ms
# 121:	learn: 0.3117654	total: 151ms	remaining: 469ms
# 122:	learn: 0.3110434	total: 153ms	remaining: 468ms
# 123:	learn: 0.3099985	total: 154ms	remaining: 467ms
# 124:	learn: 0.3087365	total: 156ms	remaining: 467ms
# 125:	learn: 0.3079993	total: 157ms	remaining: 466ms
# 126:	learn: 0.3070693	total: 158ms	remaining: 464ms
# 127:	learn: 0.3060972	total: 159ms	remaining: 463ms
# 128:	learn: 0.3056745	total: 161ms	remaining: 462ms
# 129:	learn: 0.3048766	total: 162ms	remaining: 461ms
# 130:	learn: 0.3036284	total: 163ms	remaining: 460ms
# 131:	learn: 0.3028024	total: 164ms	remaining: 458ms
# 132:	learn: 0.3024479	total: 165ms	remaining: 456ms
# 133:	learn: 0.3014037	total: 167ms	remaining: 455ms
# 134:	learn: 0.3006026	total: 168ms	remaining: 454ms
# 135:	learn: 0.2996410	total: 169ms	remaining: 453ms
# 136:	learn: 0.2991042	total: 171ms	remaining: 452ms
# 137:	learn: 0.2984519	total: 172ms	remaining: 450ms
# 138:	learn: 0.2977107	total: 173ms	remaining: 449ms
# 139:	learn: 0.2970164	total: 174ms	remaining: 448ms
# 140:	learn: 0.2959886	total: 175ms	remaining: 447ms
# 141:	learn: 0.2952212	total: 177ms	remaining: 446ms
# 142:	learn: 0.2947594	total: 178ms	remaining: 444ms
# 143:	learn: 0.2940824	total: 179ms	remaining: 443ms
# 144:	learn: 0.2934720	total: 180ms	remaining: 441ms
# 145:	learn: 0.2928325	total: 181ms	remaining: 440ms
# 146:	learn: 0.2922156	total: 183ms	remaining: 439ms
# 147:	learn: 0.2916167	total: 184ms	remaining: 437ms
# 148:	learn: 0.2909157	total: 185ms	remaining: 436ms
# 149:	learn: 0.2906107	total: 186ms	remaining: 435ms
# 150:	learn: 0.2897691	total: 188ms	remaining: 433ms
# 151:	learn: 0.2892443	total: 190ms	remaining: 434ms
# 152:	learn: 0.2885941	total: 191ms	remaining: 433ms
# 153:	learn: 0.2880821	total: 192ms	remaining: 432ms
# 154:	learn: 0.2873978	total: 194ms	remaining: 431ms
# 155:	learn: 0.2867554	total: 195ms	remaining: 430ms
# 156:	learn: 0.2861589	total: 196ms	remaining: 428ms
# 157:	learn: 0.2856931	total: 197ms	remaining: 427ms
# 158:	learn: 0.2850547	total: 198ms	remaining: 425ms
# 159:	learn: 0.2844798	total: 200ms	remaining: 425ms
# 160:	learn: 0.2839060	total: 201ms	remaining: 424ms
# 161:	learn: 0.2833160	total: 203ms	remaining: 423ms
# 162:	learn: 0.2826258	total: 204ms	remaining: 422ms
# 163:	learn: 0.2818895	total: 205ms	remaining: 421ms
# 164:	learn: 0.2813863	total: 207ms	remaining: 419ms
# 165:	learn: 0.2807948	total: 208ms	remaining: 419ms
# 166:	learn: 0.2799479	total: 209ms	remaining: 417ms
# 167:	learn: 0.2791447	total: 211ms	remaining: 416ms
# 168:	learn: 0.2787309	total: 212ms	remaining: 415ms
# 169:	learn: 0.2782182	total: 213ms	remaining: 414ms
# 170:	learn: 0.2774307	total: 215ms	remaining: 413ms
# 171:	learn: 0.2768490	total: 216ms	remaining: 411ms
# 172:	learn: 0.2759486	total: 217ms	remaining: 410ms
# 173:	learn: 0.2752791	total: 218ms	remaining: 409ms
# 174:	learn: 0.2748195	total: 219ms	remaining: 407ms
# 175:	learn: 0.2742113	total: 221ms	remaining: 406ms
# 176:	learn: 0.2737174	total: 222ms	remaining: 405ms
# 177:	learn: 0.2730184	total: 223ms	remaining: 404ms
# 178:	learn: 0.2727031	total: 224ms	remaining: 402ms
# 179:	learn: 0.2720902	total: 226ms	remaining: 401ms
# 180:	learn: 0.2714437	total: 227ms	remaining: 400ms
# 181:	learn: 0.2708729	total: 228ms	remaining: 398ms
# 182:	learn: 0.2704136	total: 229ms	remaining: 397ms
# 183:	learn: 0.2699636	total: 230ms	remaining: 396ms
# 184:	learn: 0.2693222	total: 232ms	remaining: 395ms
# 185:	learn: 0.2687605	total: 233ms	remaining: 393ms
# 186:	learn: 0.2680415	total: 234ms	remaining: 392ms
# 187:	learn: 0.2677767	total: 235ms	remaining: 391ms
# 188:	learn: 0.2671242	total: 237ms	remaining: 389ms
# 189:	learn: 0.2667207	total: 238ms	remaining: 388ms
# 190:	learn: 0.2659998	total: 239ms	remaining: 386ms
# 191:	learn: 0.2656471	total: 240ms	remaining: 385ms
# 192:	learn: 0.2652866	total: 241ms	remaining: 384ms
# 193:	learn: 0.2647996	total: 243ms	remaining: 383ms
# 194:	learn: 0.2643787	total: 244ms	remaining: 382ms
# 195:	learn: 0.2640688	total: 245ms	remaining: 380ms
# 196:	learn: 0.2634479	total: 246ms	remaining: 379ms
# 197:	learn: 0.2628149	total: 248ms	remaining: 378ms
# 198:	learn: 0.2624304	total: 249ms	remaining: 377ms
# 199:	learn: 0.2617990	total: 250ms	remaining: 376ms
# 200:	learn: 0.2612844	total: 252ms	remaining: 374ms
# 201:	learn: 0.2607438	total: 253ms	remaining: 373ms
# 202:	learn: 0.2603134	total: 254ms	remaining: 372ms
# 203:	learn: 0.2600385	total: 255ms	remaining: 371ms
# 204:	learn: 0.2596343	total: 257ms	remaining: 369ms
# 205:	learn: 0.2591485	total: 258ms	remaining: 368ms
# 206:	learn: 0.2588560	total: 259ms	remaining: 367ms
# 207:	learn: 0.2582249	total: 260ms	remaining: 366ms
# 208:	learn: 0.2577823	total: 262ms	remaining: 364ms
# 209:	learn: 0.2571918	total: 263ms	remaining: 363ms
# 210:	learn: 0.2568112	total: 264ms	remaining: 362ms
# 211:	learn: 0.2566634	total: 266ms	remaining: 361ms
# 212:	learn: 0.2562296	total: 267ms	remaining: 360ms
# 213:	learn: 0.2559754	total: 268ms	remaining: 358ms
# 214:	learn: 0.2556014	total: 269ms	remaining: 357ms
# 215:	learn: 0.2548244	total: 270ms	remaining: 356ms
# 216:	learn: 0.2544610	total: 272ms	remaining: 354ms
# 217:	learn: 0.2540814	total: 273ms	remaining: 353ms
# 218:	learn: 0.2537338	total: 274ms	remaining: 352ms
# 219:	learn: 0.2533920	total: 275ms	remaining: 350ms
# 220:	learn: 0.2530066	total: 276ms	remaining: 349ms
# 221:	learn: 0.2527721	total: 278ms	remaining: 348ms
# 222:	learn: 0.2525974	total: 279ms	remaining: 347ms
# 223:	learn: 0.2520269	total: 281ms	remaining: 346ms
# 224:	learn: 0.2516304	total: 282ms	remaining: 344ms
# 225:	learn: 0.2513201	total: 283ms	remaining: 343ms
# 226:	learn: 0.2508622	total: 284ms	remaining: 342ms
# 227:	learn: 0.2503770	total: 285ms	remaining: 340ms
# 228:	learn: 0.2497440	total: 287ms	remaining: 339ms
# 229:	learn: 0.2492643	total: 288ms	remaining: 338ms
# 230:	learn: 0.2487672	total: 289ms	remaining: 337ms
# 231:	learn: 0.2483913	total: 290ms	remaining: 336ms
# 232:	learn: 0.2481604	total: 292ms	remaining: 334ms
# 233:	learn: 0.2476861	total: 293ms	remaining: 333ms
# 234:	learn: 0.2470983	total: 294ms	remaining: 332ms
# 235:	learn: 0.2468043	total: 296ms	remaining: 331ms
# 236:	learn: 0.2463440	total: 297ms	remaining: 330ms
# 237:	learn: 0.2458927	total: 299ms	remaining: 329ms
# 238:	learn: 0.2454154	total: 300ms	remaining: 328ms
# 239:	learn: 0.2450100	total: 301ms	remaining: 326ms
# 240:	learn: 0.2447578	total: 303ms	remaining: 325ms
# 241:	learn: 0.2442731	total: 304ms	remaining: 324ms
# 242:	learn: 0.2439009	total: 305ms	remaining: 323ms
# 243:	learn: 0.2436141	total: 307ms	remaining: 322ms
# 244:	learn: 0.2431665	total: 308ms	remaining: 320ms
# 245:	learn: 0.2427954	total: 309ms	remaining: 319ms
# 246:	learn: 0.2425234	total: 310ms	remaining: 318ms
# 247:	learn: 0.2421009	total: 312ms	remaining: 317ms
# 248:	learn: 0.2418338	total: 313ms	remaining: 315ms
# 249:	learn: 0.2416184	total: 314ms	remaining: 314ms
# 250:	learn: 0.2412755	total: 315ms	remaining: 313ms
# 251:	learn: 0.2411242	total: 316ms	remaining: 311ms
# 252:	learn: 0.2407264	total: 318ms	remaining: 310ms
# 253:	learn: 0.2404863	total: 319ms	remaining: 309ms
# 254:	learn: 0.2399952	total: 320ms	remaining: 308ms
# 255:	learn: 0.2396670	total: 321ms	remaining: 306ms
# 256:	learn: 0.2394416	total: 322ms	remaining: 305ms
# 257:	learn: 0.2390573	total: 324ms	remaining: 304ms
# 258:	learn: 0.2385982	total: 325ms	remaining: 302ms
# 259:	learn: 0.2383697	total: 326ms	remaining: 301ms
# 260:	learn: 0.2378904	total: 328ms	remaining: 300ms
# 261:	learn: 0.2374276	total: 329ms	remaining: 299ms
# 262:	learn: 0.2371370	total: 330ms	remaining: 297ms
# 263:	learn: 0.2367099	total: 331ms	remaining: 296ms
# 264:	learn: 0.2362958	total: 332ms	remaining: 295ms
# 265:	learn: 0.2356753	total: 334ms	remaining: 293ms
# 266:	learn: 0.2349827	total: 335ms	remaining: 292ms
# 267:	learn: 0.2347702	total: 336ms	remaining: 291ms
# 268:	learn: 0.2345099	total: 337ms	remaining: 290ms
# 269:	learn: 0.2341901	total: 339ms	remaining: 288ms
# 270:	learn: 0.2338547	total: 340ms	remaining: 287ms
# 271:	learn: 0.2336269	total: 341ms	remaining: 286ms
# 272:	learn: 0.2333594	total: 342ms	remaining: 285ms
# 273:	learn: 0.2330711	total: 343ms	remaining: 283ms
# 274:	learn: 0.2327364	total: 345ms	remaining: 282ms
# 275:	learn: 0.2321922	total: 346ms	remaining: 281ms
# 276:	learn: 0.2317223	total: 347ms	remaining: 279ms
# 277:	learn: 0.2314773	total: 348ms	remaining: 278ms
# 278:	learn: 0.2311299	total: 349ms	remaining: 277ms
# 279:	learn: 0.2308566	total: 351ms	remaining: 275ms
# 280:	learn: 0.2306501	total: 352ms	remaining: 274ms
# 281:	learn: 0.2303214	total: 353ms	remaining: 273ms
# 282:	learn: 0.2299701	total: 354ms	remaining: 272ms
# 283:	learn: 0.2297368	total: 355ms	remaining: 270ms
# 284:	learn: 0.2294826	total: 357ms	remaining: 269ms
# 285:	learn: 0.2292365	total: 358ms	remaining: 268ms
# 286:	learn: 0.2289542	total: 359ms	remaining: 266ms
# 287:	learn: 0.2286989	total: 360ms	remaining: 265ms
# 288:	learn: 0.2284200	total: 361ms	remaining: 264ms
# 289:	learn: 0.2282543	total: 363ms	remaining: 263ms
# 290:	learn: 0.2279185	total: 364ms	remaining: 261ms
# 291:	learn: 0.2274558	total: 365ms	remaining: 260ms
# 292:	learn: 0.2270940	total: 366ms	remaining: 259ms
# 293:	learn: 0.2269825	total: 367ms	remaining: 257ms
# 294:	learn: 0.2266814	total: 368ms	remaining: 256ms
# 295:	learn: 0.2262865	total: 369ms	remaining: 255ms
# 296:	learn: 0.2260543	total: 371ms	remaining: 253ms
# 297:	learn: 0.2257282	total: 372ms	remaining: 252ms
# 298:	learn: 0.2253606	total: 373ms	remaining: 251ms
# 299:	learn: 0.2252006	total: 374ms	remaining: 250ms
# 300:	learn: 0.2249369	total: 376ms	remaining: 248ms
# 301:	learn: 0.2247318	total: 377ms	remaining: 247ms
# 302:	learn: 0.2245045	total: 378ms	remaining: 246ms
# 303:	learn: 0.2242044	total: 380ms	remaining: 245ms
# 304:	learn: 0.2239000	total: 381ms	remaining: 244ms
# 305:	learn: 0.2234057	total: 382ms	remaining: 242ms
# 306:	learn: 0.2229669	total: 383ms	remaining: 241ms
# 307:	learn: 0.2227650	total: 385ms	remaining: 240ms
# 308:	learn: 0.2224977	total: 386ms	remaining: 238ms
# 309:	learn: 0.2222002	total: 387ms	remaining: 237ms
# 310:	learn: 0.2218472	total: 388ms	remaining: 236ms
# 311:	learn: 0.2215612	total: 389ms	remaining: 235ms
# 312:	learn: 0.2213577	total: 390ms	remaining: 233ms
# 313:	learn: 0.2211250	total: 391ms	remaining: 232ms
# 314:	learn: 0.2208670	total: 393ms	remaining: 231ms
# 315:	learn: 0.2205204	total: 394ms	remaining: 229ms
# 316:	learn: 0.2202540	total: 395ms	remaining: 228ms
# 317:	learn: 0.2200939	total: 396ms	remaining: 227ms
# 318:	learn: 0.2198811	total: 397ms	remaining: 225ms
# 319:	learn: 0.2196594	total: 399ms	remaining: 224ms
# 320:	learn: 0.2194761	total: 400ms	remaining: 223ms
# 321:	learn: 0.2191371	total: 401ms	remaining: 222ms
# 322:	learn: 0.2189436	total: 402ms	remaining: 220ms
# 323:	learn: 0.2187560	total: 403ms	remaining: 219ms
# 324:	learn: 0.2185532	total: 404ms	remaining: 218ms
# 325:	learn: 0.2181120	total: 405ms	remaining: 216ms
# 326:	learn: 0.2179292	total: 406ms	remaining: 215ms
# 327:	learn: 0.2176768	total: 408ms	remaining: 214ms
# 328:	learn: 0.2173442	total: 409ms	remaining: 213ms
# 329:	learn: 0.2171649	total: 410ms	remaining: 211ms
# 330:	learn: 0.2168720	total: 412ms	remaining: 210ms
# 331:	learn: 0.2166113	total: 413ms	remaining: 209ms
# 332:	learn: 0.2162182	total: 414ms	remaining: 208ms
# 333:	learn: 0.2160489	total: 415ms	remaining: 206ms
# 334:	learn: 0.2157929	total: 417ms	remaining: 205ms
# 335:	learn: 0.2154823	total: 418ms	remaining: 204ms
# 336:	learn: 0.2152086	total: 419ms	remaining: 203ms
# 337:	learn: 0.2147994	total: 421ms	remaining: 202ms
# 338:	learn: 0.2147787	total: 421ms	remaining: 200ms
# 339:	learn: 0.2145009	total: 423ms	remaining: 199ms
# 340:	learn: 0.2141846	total: 424ms	remaining: 198ms
# 341:	learn: 0.2140508	total: 425ms	remaining: 196ms
# 342:	learn: 0.2138330	total: 426ms	remaining: 195ms
# 343:	learn: 0.2138215	total: 427ms	remaining: 194ms
# 344:	learn: 0.2136569	total: 428ms	remaining: 192ms
# 345:	learn: 0.2132977	total: 429ms	remaining: 191ms
# 346:	learn: 0.2131679	total: 431ms	remaining: 190ms
# 347:	learn: 0.2129743	total: 432ms	remaining: 189ms
# 348:	learn: 0.2127192	total: 433ms	remaining: 187ms
# 349:	learn: 0.2124759	total: 434ms	remaining: 186ms
# 350:	learn: 0.2121668	total: 436ms	remaining: 185ms
# 351:	learn: 0.2120352	total: 437ms	remaining: 184ms
# 352:	learn: 0.2118592	total: 438ms	remaining: 183ms
# 353:	learn: 0.2115787	total: 440ms	remaining: 181ms
# 354:	learn: 0.2114308	total: 441ms	remaining: 180ms
# 355:	learn: 0.2111194	total: 442ms	remaining: 179ms
# 356:	learn: 0.2110851	total: 443ms	remaining: 177ms
# 357:	learn: 0.2110308	total: 444ms	remaining: 176ms
# 358:	learn: 0.2106894	total: 446ms	remaining: 175ms
# 359:	learn: 0.2105507	total: 447ms	remaining: 174ms
# 360:	learn: 0.2103838	total: 448ms	remaining: 172ms
# 361:	learn: 0.2100840	total: 449ms	remaining: 171ms
# 362:	learn: 0.2097950	total: 450ms	remaining: 170ms
# 363:	learn: 0.2095080	total: 452ms	remaining: 169ms
# 364:	learn: 0.2092702	total: 453ms	remaining: 168ms
# 365:	learn: 0.2089931	total: 454ms	remaining: 166ms
# 366:	learn: 0.2086997	total: 456ms	remaining: 165ms
# 367:	learn: 0.2085229	total: 457ms	remaining: 164ms
# 368:	learn: 0.2082182	total: 458ms	remaining: 163ms
# 369:	learn: 0.2080272	total: 459ms	remaining: 161ms
# 370:	learn: 0.2077481	total: 461ms	remaining: 160ms
# 371:	learn: 0.2075575	total: 462ms	remaining: 159ms
# 372:	learn: 0.2073359	total: 463ms	remaining: 158ms
# 373:	learn: 0.2071812	total: 464ms	remaining: 156ms
# 374:	learn: 0.2067048	total: 466ms	remaining: 155ms
# 375:	learn: 0.2064174	total: 467ms	remaining: 154ms
# 376:	learn: 0.2062012	total: 468ms	remaining: 153ms
# 377:	learn: 0.2059286	total: 469ms	remaining: 152ms
# 378:	learn: 0.2057574	total: 471ms	remaining: 150ms
# 379:	learn: 0.2054493	total: 472ms	remaining: 149ms
# 380:	learn: 0.2052026	total: 473ms	remaining: 148ms
# 381:	learn: 0.2049849	total: 474ms	remaining: 146ms
# 382:	learn: 0.2048175	total: 475ms	remaining: 145ms
# 383:	learn: 0.2045046	total: 477ms	remaining: 144ms
# 384:	learn: 0.2041795	total: 478ms	remaining: 143ms
# 385:	learn: 0.2040762	total: 479ms	remaining: 142ms
# 386:	learn: 0.2039045	total: 480ms	remaining: 140ms
# 387:	learn: 0.2037467	total: 482ms	remaining: 139ms
# 388:	learn: 0.2036414	total: 483ms	remaining: 138ms
# 389:	learn: 0.2035186	total: 484ms	remaining: 137ms
# 390:	learn: 0.2032981	total: 486ms	remaining: 135ms
# 391:	learn: 0.2029904	total: 487ms	remaining: 134ms
# 392:	learn: 0.2029030	total: 488ms	remaining: 133ms
# 393:	learn: 0.2028065	total: 489ms	remaining: 132ms
# 394:	learn: 0.2026370	total: 490ms	remaining: 130ms
# 395:	learn: 0.2024502	total: 492ms	remaining: 129ms
# 396:	learn: 0.2022723	total: 493ms	remaining: 128ms
# 397:	learn: 0.2021137	total: 494ms	remaining: 127ms
# 398:	learn: 0.2019005	total: 495ms	remaining: 125ms
# 399:	learn: 0.2014741	total: 496ms	remaining: 124ms
# 400:	learn: 0.2014511	total: 497ms	remaining: 123ms
# 401:	learn: 0.2012212	total: 498ms	remaining: 121ms
# 402:	learn: 0.2008886	total: 500ms	remaining: 120ms
# 403:	learn: 0.2007967	total: 501ms	remaining: 119ms
# 404:	learn: 0.2006228	total: 502ms	remaining: 118ms
# 405:	learn: 0.2004007	total: 503ms	remaining: 117ms
# 406:	learn: 0.2001178	total: 505ms	remaining: 115ms
# 407:	learn: 0.1999133	total: 506ms	remaining: 114ms
# 408:	learn: 0.1995890	total: 507ms	remaining: 113ms
# 409:	learn: 0.1993819	total: 509ms	remaining: 112ms
# 410:	learn: 0.1992677	total: 510ms	remaining: 110ms
# 411:	learn: 0.1991154	total: 511ms	remaining: 109ms
# 412:	learn: 0.1989073	total: 513ms	remaining: 108ms
# 413:	learn: 0.1987905	total: 514ms	remaining: 107ms
# 414:	learn: 0.1985358	total: 515ms	remaining: 106ms
# 415:	learn: 0.1982636	total: 516ms	remaining: 104ms
# 416:	learn: 0.1980944	total: 518ms	remaining: 103ms
# 417:	learn: 0.1979187	total: 519ms	remaining: 102ms
# 418:	learn: 0.1976535	total: 520ms	remaining: 101ms
# 419:	learn: 0.1974204	total: 521ms	remaining: 99.3ms
# 420:	learn: 0.1971520	total: 523ms	remaining: 98.1ms
# 421:	learn: 0.1969127	total: 524ms	remaining: 96.8ms
# 422:	learn: 0.1968446	total: 525ms	remaining: 95.6ms
# 423:	learn: 0.1964351	total: 526ms	remaining: 94.4ms
# 424:	learn: 0.1959783	total: 528ms	remaining: 93.1ms
# 425:	learn: 0.1957760	total: 529ms	remaining: 91.9ms
# 426:	learn: 0.1955804	total: 530ms	remaining: 90.6ms
# 427:	learn: 0.1953907	total: 531ms	remaining: 89.4ms
# 428:	learn: 0.1951746	total: 533ms	remaining: 88.1ms
# 429:	learn: 0.1948316	total: 534ms	remaining: 86.9ms
# 430:	learn: 0.1946494	total: 535ms	remaining: 85.6ms
# 431:	learn: 0.1945103	total: 536ms	remaining: 84.4ms
# 432:	learn: 0.1943692	total: 537ms	remaining: 83.2ms
# 433:	learn: 0.1942693	total: 539ms	remaining: 81.9ms
# 434:	learn: 0.1939277	total: 540ms	remaining: 80.7ms
# 435:	learn: 0.1936926	total: 541ms	remaining: 79.4ms
# 436:	learn: 0.1934386	total: 542ms	remaining: 78.2ms
# 437:	learn: 0.1932309	total: 544ms	remaining: 76.9ms
# 438:	learn: 0.1929908	total: 545ms	remaining: 75.7ms
# 439:	learn: 0.1927358	total: 547ms	remaining: 74.6ms
# 440:	learn: 0.1926145	total: 549ms	remaining: 73.4ms
# 441:	learn: 0.1924494	total: 550ms	remaining: 72.2ms
# 442:	learn: 0.1922493	total: 551ms	remaining: 71ms
# 443:	learn: 0.1921206	total: 553ms	remaining: 69.7ms
# 444:	learn: 0.1920234	total: 554ms	remaining: 68.5ms
# 445:	learn: 0.1919242	total: 555ms	remaining: 67.2ms
# 446:	learn: 0.1917668	total: 557ms	remaining: 66ms
# 447:	learn: 0.1914828	total: 558ms	remaining: 64.8ms
# 448:	learn: 0.1914334	total: 560ms	remaining: 63.6ms
# 449:	learn: 0.1912602	total: 561ms	remaining: 62.3ms
# 450:	learn: 0.1910950	total: 562ms	remaining: 61.1ms
# 451:	learn: 0.1910540	total: 563ms	remaining: 59.8ms
# 452:	learn: 0.1908108	total: 564ms	remaining: 58.5ms
# 453:	learn: 0.1906625	total: 565ms	remaining: 57.2ms
# 454:	learn: 0.1904735	total: 566ms	remaining: 56ms
# 455:	learn: 0.1903134	total: 568ms	remaining: 54.8ms
# 456:	learn: 0.1900634	total: 570ms	remaining: 53.6ms
# 457:	learn: 0.1899716	total: 571ms	remaining: 52.3ms
# 458:	learn: 0.1898710	total: 572ms	remaining: 51.1ms
# 459:	learn: 0.1897473	total: 573ms	remaining: 49.8ms
# 460:	learn: 0.1894449	total: 574ms	remaining: 48.6ms
# 461:	learn: 0.1891000	total: 576ms	remaining: 47.3ms
# 462:	learn: 0.1888124	total: 577ms	remaining: 46.1ms
# 463:	learn: 0.1885823	total: 578ms	remaining: 44.8ms
# 464:	learn: 0.1884277	total: 579ms	remaining: 43.6ms
# 465:	learn: 0.1882302	total: 580ms	remaining: 42.3ms
# 466:	learn: 0.1880839	total: 581ms	remaining: 41.1ms
# 467:	learn: 0.1877729	total: 583ms	remaining: 39.8ms
# 468:	learn: 0.1876953	total: 584ms	remaining: 38.6ms
# 469:	learn: 0.1873510	total: 585ms	remaining: 37.3ms
# 470:	learn: 0.1872175	total: 586ms	remaining: 36.1ms
# 471:	learn: 0.1870280	total: 587ms	remaining: 34.9ms
# 472:	learn: 0.1868224	total: 589ms	remaining: 33.6ms
# 473:	learn: 0.1865977	total: 590ms	remaining: 32.3ms
# 474:	learn: 0.1864325	total: 591ms	remaining: 31.1ms
# 475:	learn: 0.1860903	total: 592ms	remaining: 29.9ms
# 476:	learn: 0.1858458	total: 593ms	remaining: 28.6ms
# 477:	learn: 0.1855625	total: 595ms	remaining: 27.4ms
# 478:	learn: 0.1852014	total: 596ms	remaining: 26.1ms
# 479:	learn: 0.1849337	total: 597ms	remaining: 24.9ms
# 480:	learn: 0.1848408	total: 598ms	remaining: 23.6ms
# 481:	learn: 0.1847379	total: 600ms	remaining: 22.4ms
# 482:	learn: 0.1846305	total: 601ms	remaining: 21.1ms
# 483:	learn: 0.1844794	total: 602ms	remaining: 19.9ms
# 484:	learn: 0.1843723	total: 603ms	remaining: 18.7ms
# 485:	learn: 0.1841342	total: 605ms	remaining: 17.4ms
# 486:	learn: 0.1840227	total: 606ms	remaining: 16.2ms
# 487:	learn: 0.1839001	total: 607ms	remaining: 14.9ms
# 488:	learn: 0.1837657	total: 608ms	remaining: 13.7ms
# 489:	learn: 0.1836023	total: 610ms	remaining: 12.4ms
# 490:	learn: 0.1834516	total: 611ms	remaining: 11.2ms
# 491:	learn: 0.1832794	total: 612ms	remaining: 9.95ms
# 492:	learn: 0.1830817	total: 613ms	remaining: 8.71ms
# 493:	learn: 0.1829752	total: 615ms	remaining: 7.47ms
# 494:	learn: 0.1827053	total: 616ms	remaining: 6.22ms
# 495:	learn: 0.1826248	total: 617ms	remaining: 4.98ms
# 496:	learn: 0.1824462	total: 618ms	remaining: 3.73ms
# 497:	learn: 0.1822148	total: 620ms	remaining: 2.49ms
# 498:	learn: 0.1820140	total: 621ms	remaining: 1.24ms
# 499:	learn: 0.1818856	total: 622ms	remaining: 0us

# %% [markdown]
# ##### Model Evaluation

# %%
print("Train Accuracy:",catboost.score(X_train, y_train))
y_pred = catboost.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.940677966101695
# Test Accuracy: 0.9130434782608695
# Classification Report               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89        38
#            1       0.91      0.94      0.93        54
#
#     accuracy                           0.91        92
#    macro avg       0.91      0.91      0.91        92
# weighted avg       0.91      0.91      0.91        92

# %% [markdown]
# #### LGBMClassifier
# [Link](https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html)

# %%
lgbm = LGBMClassifier(learning_rate=0.01, n_estimators=300, random_state=42)
lgbm.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 454, number of negative: 372
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000230 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 386
# [LightGBM] [Info] Number of data points in the train set: 826, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.549637 -> initscore=0.199203
# [LightGBM] [Info] Start training from score 0.199203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMClassifier(learning_rate=0.01, n_estimators=300, random_state=42)

# %%
print("Train Accuracy:",lgbm.score(X_train, y_train))
y_pred = lgbm.predict(X_test)
print("Test Accuracy:",accuracy_score(y_pred, y_test))
print("Classification Report",classification_report(y_test, y_pred))
# Out:
# Train Accuracy: 0.9346246973365617
# Test Accuracy: 0.9021739130434783
# Classification Report               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88        38
#            1       0.91      0.93      0.92        54
#
#     accuracy                           0.90        92
#    macro avg       0.90      0.90      0.90        92
# weighted avg       0.90      0.90      0.90        92

# %% [markdown]
# ### Conclusions:
# > * The best test accuracy for this dataset is 91 by using the CatBoostClassifier and also LGBMClassifier
# > * The second best accuracy is 89 by :
# SVC,
# Extra Tress Clf,
# AdaBoost CLF,
# vooting and stacking clf using (svc, random forest, LR),
# XGBoost
