# %% [markdown]
# 1. Write a Pandas program to create and display a one-dimensional array-like
# object containing an array of data using Pandas module.

# %%
import pandas as pd
import numpy as np

# %%
pd_arr = pd.Series([1,2,3,4,5])
pd_arr
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# 2. Write a Pandas program to convert a Panda module Series to Python list and it's
# type.

# %%
list_arr = list(pd_arr)
list_arr
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 3. Write a Pandas program to compare the elements of the two Pandas Series.

# %%
ser1 = pd.Series(['menna','mohamed',2])
ser2 = pd.Series(['menna', 'shams',4])
ser1==ser2
# ValueError: Can only compare identically-labeled Series objects
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# 4. Write a Pandas program to change the data type of given a column or a Series.

# %%
pd_arr
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd_arr = pd_arr.astype('float')
pd_arr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %% [markdown]
# 5. Write a Pandas program to get the powers of an array values element-wise.
# Note: First array elements raised to powers from second array
# Sample data: {'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]}
#
# Expected Output:
#
#   X Y Z
#
# 0 78 84 86
#
# 1 85 94 97
#
# 2 96 89 96
#
# 3 80 83 72
#
# 4 86 86 83

# %%
df = pd.DataFrame({'X':[78,85,96,80,86],'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]})
df
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# 6. Write a Pandas program to get the first 3 rows of a given DataFrame

# %%
exam_data = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael',
'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']},
                           ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

exam_data
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
exam_data[0:3]
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %% [markdown]
# 7. Write a Pandas program to display the default index and set a column as an
# Index in a given dataframe.

# %%
test_data = pd.DataFrame([['Streat1', 'S001', 'V', 'Alberto', 'Franco', '15/05/2002', 35],
 ['Streat2', 'S002', 'V', 'Gino', 'Mcneill', '17/05/2002', 32],
  ['Streat3', 'S003', 'VI', 'Ryan', 'Parkes', '16/02/1999', 33],
   ['Streat4', 'S004', 'VI', 'Eesha', 'Hinton', '25/09/1998', 30]
],[1,2,3,4])
test_copy = test_data.copy()
test_data
# Out:
#          0     1   2        3        4           5   6
# 1  Streat1  S001   V  Alberto   Franco  15/05/2002  35
# 2  Streat2  S002   V     Gino  Mcneill  17/05/2002  32
# 3  Streat3  S003  VI     Ryan   Parkes  16/02/1999  33
# 4  Streat4  S004  VI    Eesha   Hinton  25/09/1998  30

# %%
test_data.index
# Out:
# Int64Index([1, 2, 3, 4], dtype='int64')

# %%
test_data.reset_index(inplace=True)
test_data
# Out:
#    index        0     1   2        3        4           5   6
# 0      1  Streat1  S001   V  Alberto   Franco  15/05/2002  35
# 1      2  Streat2  S002   V     Gino  Mcneill  17/05/2002  32
# 2      3  Streat3  S003  VI     Ryan   Parkes  16/02/1999  33
# 3      4  Streat4  S004  VI    Eesha   Hinton  25/09/1998  30

# %% [markdown]
# 9. Write a Pandas program to create a dataframe indexing by date and time.

# %%
test_data.rename(columns={5:'date'},inplace=True)
test_data
# Out:
#    index        0     1   2        3        4        date   6
# 0      1  Streat1  S001   V  Alberto   Franco  15/05/2002  35
# 1      2  Streat2  S002   V     Gino  Mcneill  17/05/2002  32
# 2      3  Streat3  S003  VI     Ryan   Parkes  16/02/1999  33
# 3      4  Streat4  S004  VI    Eesha   Hinton  25/09/1998  30

# %%
test_data.index = test_data['date']
test_data
# Out:
#             index        0     1   2        3        4        date   6
# date
# 15/05/2002      1  Streat1  S001   V  Alberto   Franco  15/05/2002  35
# 17/05/2002      2  Streat2  S002   V     Gino  Mcneill  17/05/2002  32
# 16/02/1999      3  Streat3  S003  VI     Ryan   Parkes  16/02/1999  33
# 25/09/1998      4  Streat4  S004  VI    Eesha   Hinton  25/09/1998  30

# %% [markdown]
# 10. Write a Pandas program to create a dataframe and set a title or name of the
# index column.

# %%
test_data.rename(columns={'index':'id'},inplace=True)
test_data
# Out:
#             id        0     1   2        3        4        date   6
# date
# 15/05/2002   1  Streat1  S001   V  Alberto   Franco  15/05/2002  35
# 17/05/2002   2  Streat2  S002   V     Gino  Mcneill  17/05/2002  32
# 16/02/1999   3  Streat3  S003  VI     Ryan   Parkes  16/02/1999  33
# 25/09/1998   4  Streat4  S004  VI    Eesha   Hinton  25/09/1998  30

# %% [markdown]
# 11. Write a Pandas program to select a specific row of given series/dataframe by
# integer index.

# %%
test_data.rename(columns={0:'st',1:'ssn',2:'v',3:'last name',4:'first name',6:'age'},inplace=True)
test_data.index = test_data['id']
# test_data.drop(test_data['id'],axis=1,inplace=True)
test_data
# Out:
#     id       st   ssn   v last name first name        date  age
# id
# 1    1  Streat1  S001   V   Alberto     Franco  15/05/2002   35
# 2    2  Streat2  S002   V      Gino    Mcneill  17/05/2002   32
# 3    3  Streat3  S003  VI      Ryan     Parkes  16/02/1999   33
# 4    4  Streat4  S004  VI     Eesha     Hinton  25/09/1998   30

# %%
test_data.iloc[2:3,:]
# Out:
#     id       st   ssn   v last name first name        date  age
# id
# 3    3  Streat3  S003  VI      Ryan     Parkes  16/02/1999   33
